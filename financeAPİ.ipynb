# %%
import requests
import pandas as pd
response = requests.get("https://www.econdb.com/api/series/?page=1&format=json").json()
response
# Out:
# {'count': 6018,
#  'pages': 602,
#  'next': 'https://www.econdb.com/api/series/?format=json&page=2',
#  'previous': None,
#  'results': [{'ticker': 'CPIUS',
#    'description': 'United States - Consumer price index',
#    'geography': 'United States',
#    'frequency': 'M',
#    'dataset': 'BLS_CU',
#    'units': None,
#    'additional_metadata': {'1:area_code': '2:U.S. city average',
#     '3:item_code': '1219:All items',
#     '1220:base_code': '1221:Current',
#     'GEO:None': '229:None'},
#    'data': {'values': [21.48,
#      21.62,
#      22.0,
#      22.0,
#      21.95,
#      22.08,
#      22.23,
#      22.4,
#      22.84,
#      22.91,
#      23.06,
#      23.41,
#      23.68,
#      23.67,
#      23.5,
#      23.82,
#      24.01,
#      24.15,
#      24.4,
#      24.43,
#      24.36,
#      24.31,
#      24.16,
#      24.05,
#      24.01,
#      23.91,
#      23.91,
#      23.92,
#      23.91,
#      23.92,
#      23.7,
#      23.7,
#      23.75,
#      23.67,
#      23.7,
# ...
